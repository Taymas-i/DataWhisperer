# %%
import pandas as pd
import numpy as np

# %%
df_customers = pd.read_csv('customers.csv')
df_order_items = pd.read_csv('order_items.csv')
df_orders = pd.read_csv('orders.csv')
df_payments = pd.read_csv('payments.csv')
df_reviews = pd.read_csv('reviews.csv')
df_products = pd.read_csv('products.csv')

# %%
list_of_clean = [df_customers, df_order_items, df_orders, df_payments, df_reviews, df_products]
for df in list_of_clean:
    print(df.columns)
# Out:
# Index(['customer_id', 'customer_city', 'customer_state'], dtype='object')
# Index(['order_id', 'product_id', 'price'], dtype='object')
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_delivered_customer_date'],
#       dtype='object')
# Index(['order_id', 'payment_type', 'payment_value'], dtype='object')
# Index(['order_id', 'review_score'], dtype='object')
# Index(['product_id', 'product_category_name_english'], dtype='object')
